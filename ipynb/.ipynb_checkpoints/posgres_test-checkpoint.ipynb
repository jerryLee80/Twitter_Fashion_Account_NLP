# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd

import json

import psycopg2 as pg2
from psycopg2.extras import RealDictCursor, Json

# %% [markdown]
# ### Functions

# %%
#function to connect to posgres db on ubuntu instance 

def con_cur_to_db():
    con = pg2.connect(host = '13.52.0.109', 
                     dbname = 'postgres',
                     user = 'postgres',
                     password = 'zoolander')
    cur = con.cursor(cursor_factory = RealDictCursor)
    return con, cur

# %%
#function to insert data into unstructured postgres db

def insert_json(data):
    con, cur = con_cur_to_db()
    for x in data:
        cur.execute('INSERT INTO all_data (data) VALUES ({});'.format(Json(x)))
    con.commit()
    con.close()

# %%
####################################

items = range(1, 500)

# write a function that will capture items in chunks of 10 from 5000, decending
bucket = []

def grab_10_items():
    
    # what is the lowest number in bucket so far?
    #start from there
    
    min_bucket = min(bucket)
    
    if items[min_bucket:-10] in bcuket:
        bucket.append(the stuff you find..)

grab_10_items()
# Out:
#   File "<ipython-input-4-41300c6d6df0>", line 14
#     bucket.append(the stuff you find..)
#                           ^
# SyntaxError: invalid syntax

# %%
prime_labels = ['gucci', 'McQueen', 'StellaMcCartney', 'Roberto_Cavalli', 'acnestudios', 'jimmychoo', 'Roberto_Cavalli',\
               'TOMFORD', 'Prada', 'akris_official']

tweet_data = []

for label in prime_labels:
    try:
        tweet_data.extend(miner.mine_user_tweets(user=label, max_pages=100, last_tweet_id=True))
    except:
        print('could not mine label:', label)
    
insert_json(tweet_data)
# Out:
# Mining tweets for: gucci
# Mining page: 1
# Mining page: 2
# Mining page: 3
# Mining page: 4
# Mining page: 5
# Mining page: 6
# Mining page: 7
# Mining page: 8
# Mining page: 9
# Mining page: 10
# Mining page: 11
# Mining page: 12
# Mining page: 13
# Mining page: 14
# Mining page: 15
# Mining page: 16
# Mining page: 17
# Mining page: 18
# Mining page: 19
# Mining page: 20
# Mining page: 21
# Mining page: 22
# Mining page: 23
# Mining page: 24
# Mining page: 25
# Mining page: 26
# Mining page: 27
# Mining page: 28
# Mining page: 29
# Mining page: 30
# Mining page: 31
# Mining page: 32
# Mining page: 33
# Mining page: 34
# Mining page: 35
# Mining page: 36
# Mining page: 37
# Mining page: 38
# Mining page: 39
# Mining page: 40
# Mining page: 41
# Mining page: 42
# Mining page: 43
# Mining page: 44
# Mining page: 45
# Mining page: 46
# Mining page: 47
# Mining page: 48
# Mining page: 49
# Mining page: 50
# Mining page: 51
# Mining page: 52
# Mining page: 53
# Mining page: 54
# Mining page: 55
# Mining page: 56
# Mining page: 57
# Mining page: 58
# Mining page: 59
# Mining page: 60
# Mining page: 61
# Mining page: 62
# Mining page: 63
# Mining page: 64
# Mining page: 65
# Mining page: 66
# Mining page: 67
# Mining page: 68
# Mining page: 69
# Mining page: 70
# Mining page: 71
# Mining page: 72
# Mining page: 73
# Mining page: 74
# Mining page: 75
# Mining page: 76
# Mining page: 77
# Mining page: 78
# Mining page: 79
# Mining page: 80
# Mining page: 81
# Mining page: 82
# Mining page: 83
# Mining page: 84
# Mining page: 85
# Mining page: 86
# Mining page: 87
# Mining page: 88
# Mining page: 89
# Mining page: 90
# Mining page: 91
# Mining page: 92
# Mining page: 93
# Mining page: 94
# Mining page: 95
# Mining page: 96
# Mining page: 97
# Mining page: 98
# Mining page: 99
# Mining page: 100
# Mining tweets for: McQueen
# Mining page: 1
# Mining page: 2
# Mining page: 3
# Mining page: 4
# Mining page: 5
# Mining page: 6
# Mining page: 7
# Mining page: 8
# Mining page: 9
# Mining page: 10
# Mining page: 11
# Mining page: 12
# Mining page: 13
# Mining page: 14
# Mining page: 15
# Mining page: 16
# Mining page: 17
# Mining page: 18
# Mining page: 19
# Mining page: 20
# Mining page: 21
# Mining page: 22
# Mining page: 23
# Mining page: 24
# Mining page: 25
# Mining page: 26
# Mining page: 27
# Mining page: 28
# Mining page: 29
# Mining page: 30
# Mining page: 31
# Mining page: 32
# Mining page: 33
# Mining page: 34
# Mining page: 35
# Mining page: 36
# Mining page: 37
# Mining page: 38
# Mining page: 39
# Mining page: 40
# Mining page: 41
# Mining page: 42
# Mining page: 43
# Mining page: 44
# Mining page: 45
# Mining page: 46
# Mining page: 47
# Mining page: 48
# Mining page: 49
# Mining page: 50
# Mining page: 51
# Mining page: 52
# Mining page: 53
# Mining page: 54
# Mining page: 55
# Mining page: 56
# Mining page: 57
# Mining page: 58
# Mining page: 59
# Mining page: 60
# Mining page: 61
# Mining page: 62
# Mining page: 63
# Mining page: 64
# Mining page: 65
# Mining page: 66
# Mining page: 67
# Mining page: 68
# Mining page: 69
# Mining page: 70
# Mining page: 71
# Mining page: 72
# Mining page: 73
# Mining page: 74
# Mining page: 75
# Mining page: 76
# Mining page: 77
# Mining page: 78
# Mining page: 79
# Mining page: 80
# Mining page: 81
# Mining page: 82
# Mining page: 83
# Mining page: 84
# Mining page: 85
# Mining page: 86
# Mining page: 87
# Mining page: 88
# Mining page: 89
# Mining page: 90
# Mining page: 91
# Mining page: 92
# Mining page: 93
# Mining page: 94
# Mining page: 95
# Mining page: 96
# Mining page: 97
# Mining page: 98
# Mining page: 99
# Mining page: 100
# Mining tweets for: StellaMcCartney
# Mining page: 1
# Mining page: 2
# Mining page: 3
# Mining page: 4
# Mining page: 5
# Mining page: 6
# Mining page: 7
# Mining page: 8
# Mining page: 9
# Mining page: 10
# Mining page: 11
# Mining page: 12
# Mining page: 13
# Mining page: 14
# Mining page: 15
# Mining page: 16
# Mining page: 17
# Mining page: 18
# Mining page: 19
# Mining page: 20
# Mining page: 21
# Mining page: 22
# Mining page: 23
# Mining page: 24
# Mining page: 25
# Mining page: 26
# Mining page: 27
# Mining page: 28
# Mining page: 29
# Mining page: 30
# Mining page: 31
# Mining page: 32
# Mining page: 33
# Mining page: 34
# Mining page: 35
# Mining page: 36
# Mining page: 37
# Mining page: 38
# Mining page: 39
# Mining page: 40
# Mining page: 41
# Mining page: 42
# Mining page: 43
# Mining page: 44
# Mining page: 45
# Mining page: 46
# Mining page: 47
# Mining page: 48
# Mining page: 49
# Mining page: 50
# Mining page: 51
# Mining page: 52
# Mining page: 53
# Mining page: 54
# Mining page: 55
# Mining page: 56
# Mining page: 57
# Mining page: 58
# Mining page: 59
# Mining page: 60
# Mining page: 61
# Mining page: 62
# Mining page: 63
# Mining page: 64
# Mining page: 65
# Mining page: 66
# Mining page: 67
# Mining page: 68
# Mining page: 69
# Mining page: 70
# Mining page: 71
# Mining page: 72
# Mining page: 73
# Mining page: 74
# Mining page: 75
# Mining page: 76
# Mining page: 77
# Mining page: 78
# Mining page: 79
# Mining page: 80
# Mining page: 81
# Mining page: 82
# Mining page: 83
# Mining page: 84
# Mining page: 85
# Mining page: 86
# Mining page: 87
# Mining page: 88
# Mining page: 89
# Mining page: 90
# Mining page: 91
# Mining page: 92
# Mining page: 93
# Mining page: 94
# Mining page: 95
# Mining page: 96
# Mining page: 97
# Mining page: 98
# Mining page: 99
# Mining page: 100
# Mining tweets for: Roberto_Cavalli
# Mining page: 1
# Mining page: 2
# Mining page: 3
# Mining page: 4
# Mining page: 5
# Mining page: 6
# Mining page: 7
# Mining page: 8
# Mining page: 9
# Mining page: 10
# Mining page: 11
# Mining page: 12
# Mining page: 13
# Mining page: 14
# Mining page: 15
# Mining page: 16
# Mining page: 17
# Mining page: 18
# Mining page: 19
# Mining page: 20
# Mining page: 21
# Mining page: 22
# Mining page: 23
# Mining page: 24
# Mining page: 25
# Mining page: 26
# Mining page: 27
# Mining page: 28
# Mining page: 29
# Mining page: 30
# Mining page: 31
# Mining page: 32
# Mining page: 33
# Mining page: 34
# Mining page: 35
# Mining page: 36
# Mining page: 37
# Mining page: 38
# Mining page: 39
# Mining page: 40
# Mining page: 41
# Mining page: 42
# Mining page: 43
# Mining page: 44
# Mining page: 45
# Mining page: 46
# Mining page: 47
# Mining page: 48
# Mining page: 49
# Mining page: 50
# Mining page: 51
# Mining page: 52
# Mining page: 53
# Mining page: 54
# Mining page: 55
# Mining page: 56
# Mining page: 57
# Mining page: 58
# Mining page: 59
# Mining page: 60
# Mining page: 61
# Mining page: 62
# Mining page: 63
# Mining page: 64
# Mining page: 65
# Mining page: 66
# Mining page: 67
# Mining page: 68
# Mining page: 69
# Mining page: 70
# Mining page: 71
# Mining page: 72
# Mining page: 73
# Mining page: 74
# Mining page: 75
# Mining page: 76
# Mining page: 77
# Mining page: 78
# Mining page: 79
# Mining page: 80
# Mining page: 81
# Mining page: 82
# Mining page: 83
# Mining page: 84
# Mining page: 85
# Mining page: 86
# Mining page: 87
# Mining page: 88
# Mining page: 89
# Mining page: 90
# Mining page: 91
# Mining page: 92
# Mining page: 93
# Mining page: 94
# Mining page: 95
# Mining page: 96
# Mining page: 97
# Mining page: 98
# Mining page: 99
# Mining page: 100
# Mining tweets for: acnestudios
# Mining page: 1
# Mining page: 2
# Mining page: 3
# Mining page: 4
# Mining page: 5
# Mining page: 6
# Mining page: 7
# Mining page: 8
# Mining page: 9
# Mining page: 10
# Mining page: 11
# Mining page: 12
# Mining page: 13
# Mining page: 14
# Mining page: 15
# Mining page: 16
# Mining page: 17
# Mining page: 18
# Mining page: 19
# Mining page: 20
# Mining page: 21
# Mining page: 22
# Mining page: 23
# Mining page: 24
# Mining page: 25
# Mining page: 26
# Mining page: 27
# Mining page: 28
# Mining page: 29
# Mining page: 30
# Mining page: 31
# Mining page: 32
# Mining page: 33
# Mining page: 34
# Mining page: 35
# Mining page: 36
# Mining page: 37
# Mining page: 38
# Mining page: 39
# Mining page: 40
# Mining page: 41
# Mining page: 42
# Mining page: 43
# Mining page: 44
# Mining page: 45
# Mining page: 46
# Mining page: 47
# Mining page: 48
# Mining page: 49
# Mining page: 50
# Mining page: 51
# Mining page: 52
# Mining page: 53
# Mining page: 54
# Mining page: 55
# Mining page: 56
# Mining page: 57
# Mining page: 58
# Mining page: 59
# Mining page: 60
# Mining page: 61
# Mining page: 62
# Mining page: 63
# Mining page: 64
# Mining page: 65
# Mining page: 66
# Mining page: 67
# Mining page: 68
# Mining page: 69
# Mining page: 70
# Mining page: 71
# Mining page: 72
# Mining page: 73
# Mining page: 74
# Mining page: 75
# Mining page: 76
# Mining page: 77
# Mining page: 78
# Mining page: 79
# Mining page: 80
# Mining page: 81
# Mining page: 82
# Mining page: 83
# Mining page: 84
# Mining page: 85
# Mining page: 86
# Mining page: 87
# Mining page: 88
# Mining page: 89
# Mining page: 90
# Mining page: 91
# Mining page: 92
# Mining page: 93
# Mining page: 94
# Mining page: 95
# Mining page: 96
# Mining page: 97
# Mining page: 98
# Mining page: 99
# Mining page: 100
# Mining tweets for: jimmychoo
# Mining page: 1
# Mining page: 2
# Mining page: 3
# Mining page: 4
# Mining page: 5
# Mining page: 6
# Mining page: 7
# Mining page: 8
# Mining page: 9
# Mining page: 10
# Mining page: 11
# Mining page: 12
# Mining page: 13
# Mining page: 14
# Mining page: 15
# Mining page: 16
# Mining page: 17
# Mining page: 18
# Mining page: 19
# Mining page: 20
# Mining page: 21
# Mining page: 22
# Mining page: 23
# Mining page: 24
# Mining page: 25
# Mining page: 26
# Mining page: 27
# Mining page: 28
# Mining page: 29
# Mining page: 30
# Mining page: 31
# Mining page: 32
# Mining page: 33
# Mining page: 34
# Mining page: 35
# Mining page: 36
# Mining page: 37
# Mining page: 38
# Mining page: 39
# Mining page: 40
# Mining page: 41
# Mining page: 42
# Mining page: 43
# Mining page: 44
# Mining page: 45
# Mining page: 46
# Mining page: 47
# Mining page: 48
# Mining page: 49
# Mining page: 50
# Mining page: 51
# Mining page: 52
# Mining page: 53
# Mining page: 54
# Mining page: 55
# Mining page: 56
# Mining page: 57
# Mining page: 58
# Mining page: 59
# Mining page: 60
# Mining page: 61
# Mining page: 62
# Mining page: 63
# Mining page: 64
# Mining page: 65
# Mining page: 66
# Mining page: 67
# Mining page: 68
# Mining page: 69
# Mining page: 70
# Mining page: 71
# Mining page: 72
# Mining page: 73
# Mining page: 74
# Mining page: 75
# Mining page: 76
# Mining page: 77
# Mining page: 78
# Mining page: 79
# Mining page: 80
# Mining page: 81
# Mining page: 82
# Mining page: 83
# Mining page: 84
# Mining page: 85
# Mining page: 86
# Mining page: 87
# Mining page: 88
# Mining page: 89
# Mining page: 90
# Mining page: 91
# Mining page: 92
# Mining page: 93
# Mining page: 94
# Mining page: 95
# Mining page: 96
# Mining page: 97
# Mining page: 98
# Mining page: 99
# Mining page: 100
# Mining tweets for: Roberto_Cavalli
# Mining page: 1
# Mining page: 2
# Mining page: 3
# Mining page: 4
# Mining page: 5
# Mining page: 6
# Mining page: 7
# Mining page: 8
# Mining page: 9
# Mining page: 10
# Mining page: 11
# Mining page: 12
# Mining page: 13
# Mining page: 14
# Mining page: 15
# Mining page: 16
# Mining page: 17
# Mining page: 18
# Mining page: 19
# Mining page: 20
# Mining page: 21
# Mining page: 22
# Mining page: 23
# Mining page: 24
# Mining page: 25
# Mining page: 26
# Mining page: 27
# Mining page: 28
# Mining page: 29
# Mining page: 30
# Mining page: 31
# Mining page: 32
# Mining page: 33
# Mining page: 34
# Mining page: 35
# Mining page: 36
# Mining page: 37
# Mining page: 38
# Mining page: 39
# Mining page: 40
# Mining page: 41
# Mining page: 42
# Mining page: 43
# Mining page: 44
# Mining page: 45
# Mining page: 46
# Mining page: 47
# Mining page: 48
# Mining page: 49
# Mining page: 50
# Mining page: 51
# Mining page: 52
# Mining page: 53
# Mining page: 54
# Mining page: 55
# Mining page: 56
# Mining page: 57
# Mining page: 58
# Mining page: 59
# Mining page: 60
# Mining page: 61
# Mining page: 62
# Mining page: 63
# Mining page: 64
# Mining page: 65
# Mining page: 66
# Mining page: 67
# Mining page: 68
# Mining page: 69
# Mining page: 70
# Mining page: 71
# Mining page: 72
# Mining page: 73
# Mining page: 74
# Mining page: 75
# Mining page: 76
# Mining page: 77
# Mining page: 78
# Mining page: 79
# Mining page: 80
# Mining page: 81
# Mining page: 82
# Mining page: 83
# Mining page: 84
# Mining page: 85
# Mining page: 86
# Mining page: 87
# Mining page: 88
# Mining page: 89
# Mining page: 90
# Mining page: 91
# Mining page: 92
# Mining page: 93
# Mining page: 94
# Mining page: 95
# Mining page: 96
# Mining page: 97
# Mining page: 98
# Mining page: 99
# Mining page: 100
# Mining tweets for: TOMFORD
# Mining page: 1
# Mining page: 2
# Mining page: 3
# Mining page: 4
# Mining page: 5
# Mining page: 6
# Mining page: 7
# Mining page: 8
# Mining page: 9
# Mining page: 10
# Mining page: 11
# Mining page: 12
# Mining page: 13
# Mining page: 14
# Mining page: 15
# Mining page: 16
# Mining page: 17
# Mining page: 18
# Mining page: 19
# Mining page: 20
# Mining page: 21
# Mining page: 22
# Mining page: 23
# Mining page: 24
# Mining page: 25
# Mining page: 26
# Mining page: 27
# Mining page: 28
# Mining page: 29
# Mining page: 30
# Mining page: 31
# Mining page: 32
# Mining page: 33
# Mining page: 34
# Mining page: 35
# Mining page: 36
# Mining page: 37
# Mining page: 38
# Mining page: 39
# Mining page: 40
# Mining page: 41
# Mining page: 42
# Mining page: 43
# Mining page: 44
# Mining page: 45
# Mining page: 46
# Mining page: 47
# Mining page: 48
# Mining page: 49
# Mining page: 50
# Mining page: 51
# Mining page: 52
# Mining page: 53
# Mining page: 54
# Mining page: 55
# Mining page: 56
# Mining page: 57
# Mining page: 58
# Mining page: 59
# Mining page: 60
# Mining page: 61
# Mining page: 62
# Mining page: 63
# Mining page: 64
# Mining page: 65
# Mining page: 66
# Mining page: 67
# Mining page: 68
# Mining page: 69
# Mining page: 70
# Mining page: 71
# Mining page: 72
# Mining page: 73
# Mining page: 74
# Mining page: 75
# Mining page: 76
# Mining page: 77
# Mining page: 78
# Mining page: 79
# Mining page: 80
# Mining page: 81
# Mining page: 82
# Mining page: 83
# Mining page: 84
# Mining page: 85
# Mining page: 86
# Mining page: 87
# Mining page: 88
# Mining page: 89
# Mining page: 90
# Mining page: 91
# Mining page: 92
# Mining page: 93
# Mining page: 94
# Mining page: 95
# Mining page: 96
# Mining page: 97
# Mining page: 98
# Mining page: 99
# Mining page: 100
# Mining tweets for: Prada
# Mining page: 1
# Mining page: 2
# Mining page: 3
# Mining page: 4
# Mining page: 5
# Mining page: 6
# Mining page: 7
# Mining page: 8
# Mining page: 9
# Mining page: 10
# Mining page: 11
# Mining page: 12
# Mining page: 13
# Mining page: 14
# Mining page: 15
# Mining page: 16
# Mining page: 17
# Mining page: 18
# Mining page: 19
# Mining page: 20
# Mining page: 21
# Mining page: 22
# Mining page: 23
# Mining page: 24
# Mining page: 25
# Mining page: 26
# Mining page: 27
# Mining page: 28
# Mining page: 29
# Mining page: 30
# Mining page: 31
# Mining page: 32
# Mining page: 33
# Mining page: 34
# Mining page: 35
# Mining page: 36
# Mining page: 37
# Mining page: 38
# Mining page: 39
# Mining page: 40
# Mining page: 41
# Mining page: 42
# Mining page: 43
# Mining page: 44
# Mining page: 45
# Mining page: 46
# Mining page: 47
# Mining page: 48
# Mining page: 49
# Mining page: 50
# Mining page: 51
# Mining page: 52
# Mining page: 53
# Mining page: 54
# Mining page: 55
# Mining page: 56
# Mining page: 57
# Mining page: 58
# Mining page: 59
# Mining page: 60
# Mining page: 61
# Mining page: 62
# Mining page: 63
# Mining page: 64
# Mining page: 65
# Mining page: 66
# Mining page: 67
# Mining page: 68
# Mining page: 69
# Mining page: 70
# Mining page: 71
# Mining page: 72
# Mining page: 73
# Mining page: 74
# Mining page: 75
# Mining page: 76
# Mining page: 77
# Mining page: 78
# Mining page: 79
# Mining page: 80
# Mining page: 81
# Mining page: 82
# Mining page: 83
# Mining page: 84
# Mining page: 85
# Mining page: 86
# Mining page: 87
# Mining page: 88
# Mining page: 89
# Mining page: 90
# Mining page: 91
# Mining page: 92
# Mining page: 93
# Mining page: 94
# Mining page: 95
# Mining page: 96
# Mining page: 97
# Mining page: 98
# Mining page: 99
# Mining page: 100
# Mining tweets for: akris_official
# Mining page: 1
# could not mine label: akris_official

# %%
#grabs data from postgres db

def fetch_data(query):
    con, cur = con_cur_to_db()
    cur.execute(query)
    data = cur.fetchall()
    con.close()
    return data

# %%
#function to run sql queries in postgres db 

def get_handle_tweets(handle):
    query = f"""
    SELECT * 
    FROM all_data
    Where data->>'handle' = 
    '{handle}'; """
    data = fetch_data(query)
    return data

# %%
#list of dict of dicts 

gucci = get_handle_tweets('gucci')

# %%
#deal with duplicates, drop_duplicates, duplicated

gucci[:2]
# Out:
# [{'data': {'created': 'Wed Mar 21 22:00:19 +0000 2018',
#    'handle': 'gucci',
#    'text': 'A fresh and green scent Gucci Bloom Acqua di Fiori, a new chapter of the Gucci Bloom #InBloom fragrance story, captured in a campaign featuring #DakotaJohnson and @petracollins https://t.co/El1buBhuCU \nPhoto by: #GlenLunchford\nArt director: #ChristopherSimmonds\n#AlessandroMichele https://t.co/dVNtSosZ0J',
#    'tweet_id': 976579281898885120}},
#  {'data': {'created': 'Wed Mar 21 20:00:19 +0000 2018',
#    'handle': 'gucci',
#    'text': 'New scent Gucci Bloom Acqua di Fiori blends a watery accord of green Galbanum and dainty Cassis buds with the flourishing garden perfume from the original fragrance https://t.co/El1buBhuCU #InBloom \nPhoto by: #GlenLunchford\nArt director: #ChristopherSimmonds\n#AlessandroMichele https://t.co/lUgkB1Hvc0',
#    'tweet_id': 976549082427740160}}]

# %%
df = pd.DataFrame.from_dict(gucci)
df.head()
# Out:
#                                                 data
# 0  {'text': 'A fresh and green scent Gucci Bloom ...
# 1  {'text': 'New scent Gucci Bloom Acqua di Fiori...
# 2  {'text': 'Presenting a new chapter of #InBloom...
# 3  {'text': '“It was my way of surviving, to char...
# 4  {'text': '.@MichaelClarkCo reveals, "Japan is ...

# %%
df.data[0]
# Out:
# {'created': 'Wed Mar 21 22:00:19 +0000 2018',
#  'handle': 'gucci',
#  'text': 'A fresh and green scent Gucci Bloom Acqua di Fiori, a new chapter of the Gucci Bloom #InBloom fragrance story, captured in a campaign featuring #DakotaJohnson and @petracollins https://t.co/El1buBhuCU \nPhoto by: #GlenLunchford\nArt director: #ChristopherSimmonds\n#AlessandroMichele https://t.co/dVNtSosZ0J',
#  'tweet_id': 976579281898885120}

# %%
json.dumps(df.data[0])
# Out:
# '{"text": "A fresh and green scent Gucci Bloom Acqua di Fiori, a new chapter of the Gucci Bloom #InBloom fragrance story, captured in a campaign featuring #DakotaJohnson and @petracollins https://t.co/El1buBhuCU \\nPhoto by: #GlenLunchford\\nArt director: #ChristopherSimmonds\\n#AlessandroMichele https://t.co/dVNtSosZ0J", "handle": "gucci", "created": "Wed Mar 21 22:00:19 +0000 2018", "tweet_id": 976579281898885120}'

# %%
df.data.map(lambda x: json.loads(x).loads('{"handle": " "}'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-be43e5f20a6a> in <module>()
# ----> 1 df.data.map(lambda x: json.loads(x).loads('{"handle": " "}'))
#
# /anaconda2/envs/dsi/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2352         else:
#    2353             # arg is a function
# -> 2354             new_values = map_f(values, arg)
#    2355
#    2356         return self._constructor(new_values,
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-68-be43e5f20a6a> in <lambda>(x)
# ----> 1 df.data.map(lambda x: json.loads(x).loads('{"handle": " "}'))
#
# /anaconda2/envs/dsi/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346         if not isinstance(s, (bytes, bytearray)):
#     347             raise TypeError('the JSON object must be str, bytes or bytearray, '
# --> 348                             'not {!r}'.format(s.__class__.__name__))
#     349         s = s.decode(detect_encoding(s), 'surrogatepass')
#     350
#
# TypeError: the JSON object must be str, bytes or bytearray, not 'dict'

# %%
df.data.map(lambda x: json.loads(x).get('handle', ''))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-17b525ba3572> in <module>()
# ----> 1 df.data.map(lambda x: json.loads(x).get('{"handle": ""}'))
#
# /anaconda2/envs/dsi/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2352         else:
#    2353             # arg is a function
# -> 2354             new_values = map_f(values, arg)
#    2355
#    2356         return self._constructor(new_values,
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-66-17b525ba3572> in <lambda>(x)
# ----> 1 df.data.map(lambda x: json.loads(x).get('{"handle": ""}'))
#
# /anaconda2/envs/dsi/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346         if not isinstance(s, (bytes, bytearray)):
#     347             raise TypeError('the JSON object must be str, bytes or bytearray, '
# --> 348                             'not {!r}'.format(s.__class__.__name__))
#     349         s = s.decode(detect_encoding(s), 'surrogatepass')
#     350
#
# TypeError: the JSON object must be str, bytes or bytearray, not 'dict'

# %%
#transform data to df
#check for duplicates and nulls
# capture hypter links

# %% [markdown]
# ### Collecting Fashion House Tweets

# %%
#Reading in application keys 

with open('../data/twitter_keys.txt') as api:
    keys = api.read().split('\n') 

#Aplication keys

import twitter, re, datetime, pandas as pd

twitter_keys = {
    'consumer_key':        keys[0],
    'consumer_secret':     keys[1],
    'access_token_key':    keys[2],
    'access_token_secret': keys[3]
}

api = twitter.Api(
    consumer_key         =   twitter_keys['consumer_key'],
    consumer_secret      =   twitter_keys['consumer_secret'],
    access_token_key     =   twitter_keys['access_token_key'],
    access_token_secret  =   twitter_keys['access_token_secret'],
    tweet_mode           =   'extended'
)

# %%
statuses = api.GetUserTimeline(screen_name="gucci", count=200, trim_user=False)
# Out:
# ---------------------------------------------------------------------------
# TwitterError                              Traceback (most recent call last)
# <ipython-input-6-ecfba6d20ee7> in <module>()
# ----> 1 statuses = api.GetUserTimeline(screen_name="gucci", count=200, trim_user=False)
#
# /anaconda2/envs/dsi/lib/python3.6/site-packages/twitter/api.py in GetUserTimeline(self, user_id, screen_name, since_id, max_id, count, include_rts, trim_user, exclude_replies)
#     809
#     810         resp = self._RequestUrl(url, 'GET', data=parameters)
# --> 811         data = self._ParseAndCheckTwitter(resp.content.decode('utf-8'))
#     812
#     813         return [Status.NewFromJsonDict(x) for x in data]
#
# /anaconda2/envs/dsi/lib/python3.6/site-packages/twitter/api.py in _ParseAndCheckTwitter(self, json_data)
#    4903                 raise TwitterError({'message': "Unauthorized"})
#    4904             raise TwitterError({'Unknown error: {0}'.format(json_data)})
# -> 4905         self._CheckForTwitterError(data)
#    4906         return data
#    4907
#
# /anaconda2/envs/dsi/lib/python3.6/site-packages/twitter/api.py in _CheckForTwitterError(data)
#    4923             raise TwitterError(data['error'])
#    4924         if 'errors' in data:
# -> 4925             raise TwitterError(data['errors'])
#    4926
#    4927     def _RequestChunkedUpload(self, url, headers, data):
#
# TwitterError: [{'message': 'Rate limit exceeded', 'code': 88}]

# %%
tweet = statuses[0]
tweet.full_text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b885d379307d> in <module>()
# ----> 1 tweet = statuses[0]
#       2 tweet.full_text
#
# NameError: name 'statuses' is not defined

# %%
[status.full_text for status in statuses]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-64d5f088ab4b> in <module>()
# ----> 1 [status.full_text for status in statuses]
#
# NameError: name 'statuses' is not defined

# %%
#Twitter API Class

class TweetMiner():
    
    result_limit = 20
    api          = None
    tweets       = []
    
    def __init__(self, keys_dict, api, result_limit = 20):
        
        self.keys_dict     = keys_dict
        self.api           = api
        self.results_limit = result_limit
        
    def mine_user_tweets(self, user='gucci', mine_retweets = False, max_pages = None, last_tweet_id = False):
        
        #time out feedback
        print("Mining tweets for:", user)
        
        tweets        = []
        last_tweet_id = False
        page           = 1
        
        while page <= max_pages:
            
            #time out feedback
            print("Mining page:", page)
            
            if last_tweet_id:
                statuses = self.api.GetUserTimeline(
                    screen_name = user,
                    count       = self.result_limit,
                    max_id      = last_tweet_id - 1
                )
            else:
                statuses = self.api.GetUserTimeline(
                    screen_name = user,
                    count       = self.result_limit
                )

            for item in statuses:
                
                last_tweet_id = item.id
                
                tweets.append({
                    'tweet_id': item.id,
                    'handle':   item.user.name,
                    'text':     item.full_text,
                    'created':  item.created_at
                })
                
            page += 1
        
        return tweets
            
        
miner = TweetMiner(twitter_keys, api, result_limit=50)

# %% [markdown]
# ### Fashion Labels

# %%
wikipedia_labels = ['akris_official', 'McQueen', 'alfreddunhill', 'AlphaIndustries', 'andres_sarda', 'Anne_Fontaine',\
                   'aquascutum', 'giorgioarmani', 'emporioarmani', 'ArmaniExchange', 'AspinalofLondon', 'AspreyLondon',\
                   'AleDellAcqua', 'Dior', 'dkny', 'dolcegabbana', '_BadgleyMischka', 'BadgleyMischka', 'BALENCIAGA',\
                   'Bally', 'Balmain', 'BensonAndClegg', 'berluti', 'Beulahlondon', 'ManoloBlahnik', 'HUGOBOSS',\
                    'BottegaVeneta', 'ThomBrowneNY', 'Bulgariofficial', 'Burberry', '']

# %%
fashion_labels = ['gucci', 'McQueen', 'StellaMcCartney', 'Fendi', 'MaisonValentino', 'Roberto_Cavalli',\
                  'LouboutinWorld', 'EtroOfficial', 'Prada', 'dolcegabbana', 'Dior', 'LouisVuitton', 'CHANEL'\
                 'Missoni', 'OscardelaRenta', 'VeraWangGang', 'HerveLeger', 'MaisonValentino', 'Balmain',\
                 'Versace', 'giorgioarmani', 'DerekLamNYC', 'AlbertaFerretti', 'YSL', 'COMMEGARCONS', 'BALENCIAGA',\
                 'Burberry', 'TOMFORD', 'ALEXVAUTHIER', 'MIUMIUofficial', 'CalvinKlein', 'givenchy', 'TommyHilfiger',\
                 'jimmychoo', 'OffWht', 'chloefashion','dkny', 'marcjacobs', 'MichaelKors', 'Goyard', 'HUGOBOSS',\
                 'kenzo', 'HELMUTLANG', 'acnestudios', 'Bulgariofficial', 'akris_official', '']

prime_labels = ['gucci', 'McQueen', 'StellaMcCartney', 'Roberto_Cavalli', 'acnestudios', 'jimmychoo', 'Roberto_Cavalli',\
               'TOMFORD', 'Prada', 'akris_official']

print('fashion_labels:', len(fashion_labels))
print('prime_labels:', len(prime_labels))
print('wikipedia_labels', len(wikipedia_labels))
# Out:
# fashion_labels: 46
# prime_labels: 10
# wikipedia_labels 31

# %%
#Instantiating class and passing list of twitter handles

tweet_data = []

for label in prime_labels:
    try:
        tweet_data = miner.mine_user_tweets(user=label, max_pages=500, last_tweet_id=True)
        df = pd.DataFrame(tweet_data)
        df.to_csv('../data/%s.csv' % label)
    except:
        print('could not mine label:', label)
# Out:
# Mining tweets for: gucci
# Mining page: 1
# Mining page: 2
# Mining page: 3
# Mining page: 4
# Mining page: 5
# Mining page: 6
# Mining page: 7
# Mining page: 8
# Mining page: 9
# Mining page: 10
# Mining page: 11
# Mining page: 12
# Mining page: 13
# Mining page: 14
# Mining page: 15
# Mining page: 16
# Mining page: 17
# Mining page: 18
# Mining page: 19
# Mining page: 20
# Mining page: 21
# Mining page: 22
# Mining page: 23
# Mining page: 24
# Mining page: 25
# Mining page: 26
# Mining page: 27
# Mining page: 28
# Mining page: 29
# Mining page: 30
# Mining page: 31
# Mining page: 32
# Mining page: 33
# Mining page: 34
# Mining page: 35
# Mining page: 36
# Mining page: 37
# Mining page: 38
# Mining page: 39
# Mining page: 40
# Mining page: 41
# Mining page: 42
# Mining page: 43
# Mining page: 44
# Mining page: 45
# Mining page: 46
# Mining page: 47
# Mining page: 48
# Mining page: 49
# Mining page: 50
# Mining page: 51
# Mining page: 52
# Mining page: 53
# Mining page: 54
# Mining page: 55
# Mining page: 56
# Mining page: 57
# Mining page: 58
# Mining page: 59
# Mining page: 60
# Mining page: 61
# Mining page: 62
# Mining page: 63
# Mining page: 64
# Mining page: 65
# Mining page: 66
# Mining page: 67
# Mining page: 68
# Mining page: 69
# Mining page: 70
# Mining page: 71
# Mining page: 72
# Mining page: 73
# Mining page: 74
# Mining page: 75
# Mining page: 76
# Mining page: 77
# Mining page: 78
# Mining page: 79
# Mining page: 80
# Mining page: 81
# Mining page: 82
# Mining page: 83
# Mining page: 84
# Mining page: 85
# Mining page: 86
# Mining page: 87
# Mining page: 88
# Mining page: 89
# Mining page: 90
# Mining page: 91
# Mining page: 92
# Mining page: 93
# Mining page: 94
# Mining page: 95
# Mining page: 96
# Mining page: 97
# Mining page: 98
# Mining page: 99
# Mining page: 100
# Mining page: 101
# Mining page: 102
# Mining page: 103
# Mining page: 104
# Mining page: 105
# Mining page: 106
# Mining page: 107
# Mining page: 108
# Mining page: 109
# Mining page: 110
# Mining page: 111
# Mining page: 112
# Mining page: 113
# Mining page: 114
# Mining page: 115
# Mining page: 116
# Mining page: 117
# Mining page: 118
# Mining page: 119
# Mining page: 120
# Mining page: 121
# Mining page: 122
# Mining page: 123
# Mining page: 124
# Mining page: 125
# Mining page: 126
# Mining page: 127
# Mining page: 128
# Mining page: 129
# Mining page: 130
# Mining page: 131
# Mining page: 132
# Mining page: 133
# Mining page: 134
# Mining page: 135
# Mining page: 136
# Mining page: 137
# Mining page: 138
# Mining page: 139
# Mining page: 140
# Mining page: 141
# Mining page: 142
# Mining page: 143
# Mining page: 144
# Mining page: 145
# Mining page: 146
# Mining page: 147
# Mining page: 148
# Mining page: 149
# Mining page: 150
# Mining page: 151
# Mining page: 152
# Mining page: 153
# Mining page: 154
# Mining page: 155
# Mining page: 156
# Mining page: 157
# Mining page: 158
# Mining page: 159
# Mining page: 160
# Mining page: 161
# Mining page: 162
# Mining page: 163
# Mining page: 164
# Mining page: 165
# Mining page: 166
# Mining page: 167
# Mining page: 168
# Mining page: 169
# Mining page: 170
# Mining page: 171
# Mining page: 172
# Mining page: 173
# Mining page: 174
# Mining page: 175
# Mining page: 176
# Mining page: 177
# Mining page: 178
# Mining page: 179
# Mining page: 180
# Mining page: 181
# Mining page: 182
# Mining page: 183
# Mining page: 184
# Mining page: 185
# Mining page: 186
# Mining page: 187
# Mining page: 188
# Mining page: 189
# Mining page: 190
# Mining page: 191
# Mining page: 192
# Mining page: 193
# Mining page: 194
# Mining page: 195
# Mining page: 196
# Mining page: 197
# Mining page: 375
# Mining page: 376
# Mining page: 377
# Mining page: 378
# Mining page: 379
# Mining page: 380
# Mining page: 381
# Mining page: 382
# Mining page: 383
# Mining page: 384
# Mining page: 385
# Mining page: 386
# Mining page: 387
# Mining page: 388
# Mining page: 389
# Mining page: 390
# Mining page: 391
# Mining page: 392
# Mining page: 393
# Mining page: 394
# Mining page: 395
# Mining page: 396
# Mining page: 397
# Mining page: 398
# Mining page: 399
# Mining page: 400
# Mining page: 401
# could not mine label: McQueen
# Mining tweets for: StellaMcCartney
# Mining page: 1
# could not mine label: StellaMcCartney
# Mining tweets for: Roberto_Cavalli
# Mining page: 1
# could not mine label: Roberto_Cavalli
# Mining tweets for: acnestudios
# Mining page: 1
# could not mine label: acnestudios
# Mining tweets for: jimmychoo
# Mining page: 1
# could not mine label: jimmychoo
# Mining tweets for: Roberto_Cavalli
# Mining page: 1
# could not mine label: Roberto_Cavalli
# Mining tweets for: TOMFORD
# Mining page: 1
# could not mine label: TOMFORD
# Mining tweets for: Prada
# Mining page: 1
# could not mine label: Prada
# Mining tweets for: akris_official
# Mining page: 1
# could not mine label: akris_official

# %%
#Instantiating class and passing list of twitter handles

tweet_data = []

for label in prime_labels:
    tweet_data.extend(miner.mine_user_tweets(user=label, max_pages=50, last_tweet_id=True))

fashion = pd.DataFrame(tweet_data)
# Out:
# Mining tweets for: gucci
# Mining page: 1
# ---------------------------------------------------------------------------
# TwitterError                              Traceback (most recent call last)
# <ipython-input-13-53c41f5b7b5f> in <module>()
#       4
#       5 for label in prime_labels:
# ----> 6     tweet_data.extend(miner.mine_user_tweets(user=label, max_pages=50, last_tweet_id=True))
#       7
#       8 fashion = pd.DataFrame(tweet_data)
#
# <ipython-input-9-8a59ee1c08a4> in mine_user_tweets(self, user, mine_retweets, max_pages, last_tweet_id)
#      36                 statuses = self.api.GetUserTimeline(
#      37                     screen_name = user,
# ---> 38                     count       = self.result_limit
#      39                 )
#      40
#
# /anaconda2/envs/dsi/lib/python3.6/site-packages/twitter/api.py in GetUserTimeline(self, user_id, screen_name, since_id, max_id, count, include_rts, trim_user, exclude_replies)
#     809
#     810         resp = self._RequestUrl(url, 'GET', data=parameters)
# --> 811         data = self._ParseAndCheckTwitter(resp.content.decode('utf-8'))
#     812
#     813         return [Status.NewFromJsonDict(x) for x in data]
#
# /anaconda2/envs/dsi/lib/python3.6/site-packages/twitter/api.py in _ParseAndCheckTwitter(self, json_data)
#    4903                 raise TwitterError({'message': "Unauthorized"})
#    4904             raise TwitterError({'Unknown error: {0}'.format(json_data)})
# -> 4905         self._CheckForTwitterError(data)
#    4906         return data
#    4907
#
# /anaconda2/envs/dsi/lib/python3.6/site-packages/twitter/api.py in _CheckForTwitterError(data)
#    4923             raise TwitterError(data['error'])
#    4924         if 'errors' in data:
# -> 4925             raise TwitterError(data['errors'])
#    4926
#    4927     def _RequestChunkedUpload(self, url, headers, data):
#
# TwitterError: [{'message': 'Rate limit exceeded', 'code': 88}]

# %%
fashion.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0ec3a7c063d1> in <module>()
# ----> 1 fashion.shape
#
# NameError: name 'fashion' is not defined

# %%
fashion.groupby(fashion.handle).size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-a47fcbb365e1> in <module>()
# ----> 1 fashion.groupby(fashion.handle).size()
#
# NameError: name 'fashion' is not defined

# %%
fashion.to_pickle('../data/fashion.pkl')

# %%
fashion.head()
# Out:
#                           created handle  \
# 0  Wed Mar 21 22:00:19 +0000 2018  gucci
# 1  Wed Mar 21 20:00:19 +0000 2018  gucci
# 2  Wed Mar 21 17:59:41 +0000 2018  gucci
# 3  Tue Mar 20 19:00:35 +0000 2018  gucci
# 4  Tue Mar 20 16:00:39 +0000 2018  gucci
#
#                                                 text            tweet_id
# 0  A fresh and green scent Gucci Bloom Acqua di F...  976579281898885120
# 1  New scent Gucci Bloom Acqua di Fiori blends a ...  976549082427740160
# 2  Presenting a new chapter of #InBloom, Gucci Bl...  976518722830716931
# 3  “It was my way of surviving, to charm people o...  976171664982659073
# 4  .@MichaelClarkCo reveals, "Japan is the most a...  976126380206383104

# %%
gucci_db = pd.read_csv('../data/gucci.csv', index_col=[0])
gucci_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3241 entries, 0 to 3233
# Data columns (total 4 columns):
# created     3241 non-null object
# handle      3234 non-null object
# text        3234 non-null object
# tweet_id    3227 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 126.6+ KB

# %%
gucci_db.isnull().sum()
# Out:
# created      0
# handle       7
# text         7
# tweet_id    14
# dtype: int64

# %%
gucci_db[gucci_db.duplicated('tweet_id')]
# Out:
#                                                                            created  \
# #GucciCruise18 dress by #AlessandroMichele. #Gu...              948291441901654016
# 333                                                 Tue Jan 02 15:05:10 +0000 2018
# #AlessandroMichele for @britishvogue. #GucciEdi...              948208551297732608
# 535                                                 Sun Nov 05 15:26:31 +0000 2017
# #InBloom https://t.co/CIasySNAxd                                927195431150477312
# 537                                                 Sun Nov 05 14:31:10 +0000 2017
# silk gown. https://t.co/IHR2yp2iTn                              927181499400708096
# 861                                                 Thu Aug 17 11:01:56 +0000 2017
# #AlessandroMichele https://t.co/koYWlem9Az                      898137814101000192
# 867                                                 Sun Aug 13 14:26:34 +0000 2017
# August issue. #GucciEditorials https://t.co/xdg...              896739761288871936
# 943                                                 Sun Jul 16 19:10:01 +0000 2017
# from #GucciPreFall17. https://t.co/qEZ0CKtPTf                   886664234473541633
#
#                                                    handle  \
# #GucciCruise18 dress by #AlessandroMichele. #Gu...    NaN
# 333                                                 gucci
# #AlessandroMichele for @britishvogue. #GucciEdi...    NaN
# 535                                                 gucci
# #InBloom https://t.co/CIasySNAxd                      NaN
# 537                                                 gucci
# silk gown. https://t.co/IHR2yp2iTn                    NaN
# 861                                                 gucci
# #AlessandroMichele https://t.co/koYWlem9Az            NaN
# 867                                                 gucci
# August issue. #GucciEditorials https://t.co/xdg...    NaN
# 943                                                 gucci
# from #GucciPreFall17. https://t.co/qEZ0CKtPTf         NaN
#
#                                                                                                  text  \
# #GucciCruise18 dress by #AlessandroMichele. #Gu...                                                NaN
# 333                                                 Actress Kristin Scott Thomas is captured in th...
# #AlessandroMichele for @britishvogue. #GucciEdi...                                                NaN
# 535                                                 @petrafcollins at last night’s @lacma #artandf...
# #InBloom https://t.co/CIasySNAxd                                                                  NaN
# 537                                                 .#AmyAdams attended @lacma’s #artandfilm Gala ...
# silk gown. https://t.co/IHR2yp2iTn                                                                NaN
# 861                                                 Floral prints and lace pumps featuring a strap...
# #AlessandroMichele https://t.co/koYWlem9Az                                                        NaN
# 867                                                 A trench coat and the #GucciBambooClassic bag ...
# August issue. #GucciEditorials https://t.co/xdg...                                                NaN
# 943                                                 Embroidered flowers and the House Web stripe o...
# from #GucciPreFall17. https://t.co/qEZ0CKtPTf                                                     NaN
#
#                                                     tweet_id
# #GucciCruise18 dress by #AlessandroMichele. #Gu...       NaN
# 333                                                      NaN
# #AlessandroMichele for @britishvogue. #GucciEdi...       NaN
# 535                                                      NaN
# #InBloom https://t.co/CIasySNAxd                         NaN
# 537                                                      NaN
# silk gown. https://t.co/IHR2yp2iTn                       NaN
# 861                                                      NaN
# #AlessandroMichele https://t.co/koYWlem9Az               NaN
# 867                                                      NaN
# August issue. #GucciEditorials https://t.co/xdg...       NaN
# 943                                                      NaN
# from #GucciPreFall17. https://t.co/qEZ0CKtPTf            NaN

# %%
pd.read_csv('../data/StellaMcCartney.csv', index_col=[0]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3219 entries, 0 to 3218
# Data columns (total 4 columns):
# created     3219 non-null object
# handle      3219 non-null object
# text        3219 non-null object
# tweet_id    3219 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 125.7+ KB

# %%
pd.read_csv('../data/Roberto_Cavalli.csv', index_col=[0]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 4 columns):
# created     1000 non-null object
# handle      1000 non-null object
# text        1000 non-null object
# tweet_id    1000 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 39.1+ KB

# %%
mcqueen_db = pd.read_csv('../data/McQueen.csv', index_col=[0])
mcqueen_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1002 entries, 0 to 999
# Data columns (total 4 columns):
# created     1002 non-null object
# handle      1000 non-null object
# text        1000 non-null object
# tweet_id    998 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 39.1+ KB
# (1002, 4)

# %%
mcqueen_db.shape
# Out:
# (1002, 4)

# %%
mcqueen_db.iloc[570:590,:]
# Out:
#                                                                         created  \
# 570                                              Sat Jun 17 08:05:33 +0000 2017
# 571                                              Fri Jun 16 09:47:36 +0000 2017
# 572                                              Tue Jun 13 22:25:31 +0000 2017
# 573                                              Tue Jun 13 22:22:37 +0000 2017
# 574                                              Mon Jun 12 19:01:53 +0000 2017
# 575                                              Mon Jun 12 17:55:53 +0000 2017
# 576                                              Sun Jun 11 08:20:06 +0000 2017
# 577                                              Sat Jun 10 07:45:10 +0000 2017
# 578                                              Fri Jun 09 18:53:24 +0000 2017
# 579                                              Thu Jun 08 17:51:57 +0000 2017
# 580                                              Tue Jun 06 09:50:47 +0000 2017
# https://t.co/ce8jq2BgnA https://t.co/BDd4Ot5R7Z              872027984357675009
# 581                                              Mon Jun 05 17:10:40 +0000 2017
# 582                                              Mon Jun 05 15:57:23 +0000 2017
# https://t.co/ce8jq2BgnA https://t.co/qReYb6SaKS              871757853715050496
# 583                                              Sat Jun 03 15:48:39 +0000 2017
# 584                                              Sat Jun 03 08:56:07 +0000 2017
# 585                                              Fri Jun 02 16:02:55 +0000 2017
# 586                                              Thu Jun 01 13:17:59 +0000 2017
# 587                                              Wed May 31 22:20:05 +0000 2017
#
#                                                             handle  \
# 570                                              Alexander McQueen
# 571                                              Alexander McQueen
# 572                                              Alexander McQueen
# 573                                              Alexander McQueen
# 574                                              Alexander McQueen
# 575                                              Alexander McQueen
# 576                                              Alexander McQueen
# 577                                              Alexander McQueen
# 578                                              Alexander McQueen
# 579                                              Alexander McQueen
# 580                                              Alexander McQueen
# https://t.co/ce8jq2BgnA https://t.co/BDd4Ot5R7Z                NaN
# 581                                              Alexander McQueen
# 582                                              Alexander McQueen
# https://t.co/ce8jq2BgnA https://t.co/qReYb6SaKS                NaN
# 583                                              Alexander McQueen
# 584                                              Alexander McQueen
# 585                                              Alexander McQueen
# 586                                              Alexander McQueen
# 587                                              Alexander McQueen
#
#                                                                                               text  \
# 570                                              Flora and fauna, real and imagined, are hand-e...
# 571                                              Men's tailoring features London maps and safet...
# 572                                              This #McQueenBoxBag features hand-cut mineral ...
# 573                                              The Box Bag adorned with semi-precious labrado...
# 574                                              IN DETAIL: this lily pad top is hand-embroider...
# 575                                              A top with lily pad sequin embroidery on invis...
# 576                                              CLOSE-UP: a detail of the lily pad sequin embr...
# 577                                              An evening dress is embroidered with sequin li...
# 578                                              A tubular choker in antique gold and silver is...
# 579                                              An antique gold and silver earring with a hand...
# 580                                              A #McQueenPreAW17 dress with a gathered neckli...
# https://t.co/ce8jq2BgnA https://t.co/BDd4Ot5R7Z                                                NaN
# 581                                              CLOSE-UP: Pre AW17 black leather gloves and a ...
# 582                                              A #McQueenPreAW17 shirt dress made from a cris...
# https://t.co/ce8jq2BgnA https://t.co/qReYb6SaKS                                                NaN
# 583                                              Inspiration for #McQueenPreAW17: the workshops...
# 584                                              Inspired by the work of #BarbaraHepworth, a rh...
# 585                                              Inspired by the sculpture of #BarbaraHepworth,...
# 586                                              A medieval inspired sweater dress with lace-up...
# 587                                              The Four Ring clutch, embroidered with wings a...
#
#                                                      tweet_id
# 570                                              8.759878e+17
# 571                                              8.756511e+17
# 572                                              8.747546e+17
# 573                                              8.747539e+17
# 574                                              8.743410e+17
# 575                                              8.743244e+17
# 576                                              8.738171e+17
# 577                                              8.734459e+17
# 578                                              8.732517e+17
# 579                                              8.728738e+17
# 580                                                       NaN
# https://t.co/ce8jq2BgnA https://t.co/BDd4Ot5R7Z           NaN
# 581                                              8.717763e+17
# 582                                                       NaN
# https://t.co/ce8jq2BgnA https://t.co/qReYb6SaKS           NaN
# 583                                              8.710309e+17
# 584                                              8.709271e+17
# 585                                              8.706721e+17
# 586                                              8.702682e+17
# 587                                              8.700422e+17

# %%
mcqueen_db.isnull().sum()
# Out:
# created     0
# handle      2
# text        2
# tweet_id    4
# dtype: int64

# %%
mcqueen_db[mcqueen_db.tweet_id.isnull()]
# Out:
#                                                                         created  \
# 580                                              Tue Jun 06 09:50:47 +0000 2017
# https://t.co/ce8jq2BgnA https://t.co/BDd4Ot5R7Z              872027984357675009
# 582                                              Mon Jun 05 15:57:23 +0000 2017
# https://t.co/ce8jq2BgnA https://t.co/qReYb6SaKS              871757853715050496
#
#                                                             handle  \
# 580                                              Alexander McQueen
# https://t.co/ce8jq2BgnA https://t.co/BDd4Ot5R7Z                NaN
# 582                                              Alexander McQueen
# https://t.co/ce8jq2BgnA https://t.co/qReYb6SaKS                NaN
#
#                                                                                               text  \
# 580                                              A #McQueenPreAW17 dress with a gathered neckli...
# https://t.co/ce8jq2BgnA https://t.co/BDd4Ot5R7Z                                                NaN
# 582                                              A #McQueenPreAW17 shirt dress made from a cris...
# https://t.co/ce8jq2BgnA https://t.co/qReYb6SaKS                                                NaN
#
#                                                  tweet_id
# 580                                                   NaN
# https://t.co/ce8jq2BgnA https://t.co/BDd4Ot5R7Z       NaN
# 582                                                   NaN
# https://t.co/ce8jq2BgnA https://t.co/qReYb6SaKS       NaN

# %%
mcqueen_db.duplicated('tweet_id').sum()
# Out:
# 3
